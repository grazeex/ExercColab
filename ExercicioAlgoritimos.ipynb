# %% [markdown]
# <a href="https://colab.research.google.com/github/grazeex/ExercColab/blob/main/ExercicioAlgoritimos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios aritiméticos

# %% [markdown]
# 1° Faça um algoritmo para ler dois números e imprimir a soma dos números lidos.

# %% [markdown]
# ## Algoritimo
#
# 1. Leia o primeiro número e guarde numa variável chamada num1
#
# 2. Leia o segundo número e guarde numa variável chamada num2
#
# 3. Faça a soma das duas variáveis e guarde em outra variável chamada soma
#
# 4. Mostre o resultado

# %%
num1 = 23
num2 = 36
soma = num1 + num2
print = (f'O resultado é {soma}')

# %% [markdown]
# 2° Faça um algoritmo para ler três números e imprimir a soma, média e produto dos números lidos.

# %% [markdown]
# ## Algoritimo
#
# 1. Leia o primeiro número e guarde na variável chamada num1
# 2. Leia o segundo número e guarde na variável chamada num2
# 3. Leia o terceiro número e guarde na variável chamada num3
# 4. Faça a soma das três variável e mostre o resultado
# 5. Calcule a média das três variáveis
# 6. Mostre o resultado do produto das variáveis

# %%
num1 = 34
num2 = 36
num3 = 20
soma = num1 + num2 + num3
media = soma / 3
produto = num1 * num2 * num3
print = (f'Resulado da soma {soma}, resultado da média {media}, resultado do produto {produto}')

# %% [markdown]
# 3° Faça um algoritmo para ler dois números e imprimir o maior, o menor ou então dizer se são iguais

# %% [markdown]
# ## Algoritimo
# 1. Leia o primeiro número e guarde na variável chamada num1
# 2. Leia o segundo número e guarde na variável chamada num2
# 3. Descobir e mostrar o maior
# 4. Descobrir e mostrar o menor
# 5. Descobrir e mostrar se forem iguais

# %%
num1 = float(input("Digite um número"))
num2 = float(input("Digite outro número"))

if num1 > num2:
  print(f'O número maior é {num1}')
  print(f'O número menor é {num2}')
elif num2 > num1:
  print(f'O número maior é {num2}')
  print(f'O número menor é {num1}')
else:
  print('Os números são iguais')
# Out:
# Digite um número56
# Digite outro número66
# O número maior é 66.0
# O número menor é 56.0

# %% [markdown]
# 4° Faça um algoritmo para ler um número inteiro e dizer se o número lido é par ou impar.

# %% [markdown]
# ## Algoritimo
#
# 1. Leia o primeiro número inteiro e guarde numa variável chamada num1
# 2. Faça a divisão por 2
# 3. Se tiver resto o número é impar, se não é par
# 3. Mostre o resultado

# %%
num1 = 40
if num1 % 2 == 0:
  print = (f'O número {num1} é par')
else:
  print: (f'O numero {num1} é impár')

# %% [markdown]
# 5° Faça um algoritmo para ler dois números A e B e dizer se A é divisível por B.

# %% [markdown]
# ## Algoritimo
# 1. Leia um número e guarde numa variável A
# 2. Leia um número e guarde numa variável B
# 3. Verifique se A é divisivel por B
#  - se o resto for maior que 0 mostre que é divisivel
# - se não mostre que não é divisivel

# %%
A = int(input('Digite um número:'))
B = int(input('Digite outro número:'))

if A % B == 0:
  print(f'O numero {A} é divisível por {B}')
else:
  print(f'O número {A} não é divisivel por {B}')
# Out:
# Digite um número:100
# Digite outro número:5
# O numero 100 é divisível por 5

# %% [markdown]
# 6° Faça um algoritmo para ler dois números e imprimi-los em ordem crescente.

# %% [markdown]
# 1. Leia um numero e guarde numa variavel num1
# 2. Leia um numero e guarde numa variavel num2
# 3. Verifica qual numero é menor
# 4. Verifica qual numero é maior

# %%
num1 = int(input('Digite um número: '))
num2 = int(input('Digite outro número: '))

if num1 > num2:
  print(f'O {num1} é menor que o {num2} ')
else:
  print(f'O {num2} é maior que o {num1}')
# Out:
# Digite um número: 293
# Digite outro número: 300
# O 300 é maior que o 293

# %% [markdown]
# 7° Faça um algoritmo para ler três números e imprimir o maior.

# %% [markdown]
# ## Algoritimo
# 1. Leia um numero e guarde numa variável num1
# 2. Leia um numero e guarde numa variavel num2
# 3. Leia um numero e guarde numa variavel num3
# 4. Verifique qual é o menor numero
# 5. Verifique qual é o maior número
# 6. Mostre o resultado
